# %%
import cobra
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e8543d93f282> in <module>
# ----> 1 import cobra
#
# ModuleNotFoundError: No module named 'cobra'

# %%
pip install cobra
# Out:
# Collecting cobra
#   Downloading cobra-0.24.0-py2.py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 5.0 MB/s
# Collecting rich>=8.0
#   Downloading rich-11.2.0-py3-none-any.whl (217 kB)
#      |████████████████████████████████| 217 kB 55.8 MB/s
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 71.9 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: importlib-resources in /srv/conda/envs/notebook/lib/python3.6/site-packages (from cobra) (5.4.0)
# Collecting depinfo~=1.7
#   Downloading depinfo-1.7.0-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: pandas~=1.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from cobra) (1.1.5)
# Requirement already satisfied: numpy~=1.13 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from cobra) (1.19.5)
# Collecting optlang~=1.5
#   Downloading optlang-1.5.2-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 62.9 MB/s
# Collecting pydantic~=1.6
#   Downloading pydantic-1.9.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 28.2 MB/s
# Collecting python-libsbml==5.19.2
#   Downloading python_libsbml-5.19.2-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 65.5 MB/s
# Collecting swiglpk
#   Downloading swiglpk-5.0.4-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 15.5 MB/s
# Collecting appdirs~=1.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting diskcache~=5.0
#   Downloading diskcache-5.4.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 4.8 MB/s
# Requirement already satisfied: ruamel.yaml~=0.16 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from cobra) (0.17.16)
# Collecting httpx~=0.14
#   Downloading httpx-0.22.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 4.4 MB/s
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.6/site-packages (from depinfo~=1.7->cobra) (4.8.1)
# Requirement already satisfied: async-generator in /srv/conda/envs/notebook/lib/python3.6/site-packages (from httpx~=0.14->cobra) (1.10)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.6/site-packages (from httpx~=0.14->cobra) (2021.5.30)
# Requirement already satisfied: sniffio in /srv/conda/envs/notebook/lib/python3.6/site-packages (from httpx~=0.14->cobra) (1.2.0)
# Requirement already satisfied: charset-normalizer in /srv/conda/envs/notebook/lib/python3.6/site-packages (from httpx~=0.14->cobra) (2.0.9)
# Collecting httpcore<0.15.0,>=0.14.5
#   Downloading httpcore-0.14.7-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 9.7 MB/s
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sympy>=1.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from optlang~=1.5->cobra) (1.8)
# Requirement already satisfied: six>=1.9 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from optlang~=1.5->cobra) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pandas~=1.0->cobra) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pandas~=1.0->cobra) (2021.3)
# Requirement already satisfied: dataclasses>=0.6 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pydantic~=1.6->cobra) (0.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from pydantic~=1.6->cobra) (4.0.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from rich>=8.0->cobra) (2.10.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from rich>=8.0->cobra) (0.4.4)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 10.5 MB/s
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from ruamel.yaml~=0.16->cobra) (0.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from importlib-resources->cobra) (3.6.0)
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 5.4 MB/s
# Requirement already satisfied: anyio==3.* in /srv/conda/envs/notebook/lib/python3.6/site-packages (from httpcore<0.15.0,>=0.14.5->httpx~=0.14->cobra) (3.3.2)
# Requirement already satisfied: contextvars>=2.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from sniffio->httpx~=0.14->cobra) (2.4)
# Requirement already satisfied: idna>=2.8 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from anyio==3.*->httpcore<0.15.0,>=0.14.5->httpx~=0.14->cobra) (3.1)
# Requirement already satisfied: mpmath>=0.19 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from sympy>=1.0->optlang~=1.5->cobra) (1.2.1)
# Requirement already satisfied: immutables>=0.9 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from contextvars>=2.1->sniffio->httpx~=0.14->cobra) (0.16)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=653c90abcdb2bcec62caa299865c7915031f78407f6616228a6045b7fc2f69b9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94
# Successfully built future
# Installing collected packages: rfc3986, h11, swiglpk, httpcore, commonmark, rich, python-libsbml, pydantic, optlang, httpx, future, diskcache, depinfo, appdirs, cobra
# Successfully installed appdirs-1.4.4 cobra-0.24.0 commonmark-0.9.1 depinfo-1.7.0 diskcache-5.4.0 future-0.18.2 h11-0.12.0 httpcore-0.14.7 httpx-0.22.0 optlang-1.5.2 pydantic-1.9.0 python-libsbml-5.19.2 rfc3986-1.5.0 rich-11.2.0 swiglpk-5.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import cobra

# %%
 cobra_config = cobra.Configuration()

# %%
cobra_config.lower_bound
# Out:
# -1000.0

# %%
cobra_config.upper_bound
# Out:
# 1000.0

# %%
from cobra import Model, Reaction, Metabolite

model = Model('ejemploFBA')

## Metabolites

A = Metabolite('A',name='A', compartment='c')
B = Metabolite('B',name='B', compartment='c')
C = Metabolite('C',name='C', compartment='c')
D = Metabolite('D',name='D', compartment='c')
E = Metabolite('E',name='E', compartment='c')
F = Metabolite('F',name='F', compartment='c')
G = Metabolite('G',name='G', compartment='c')
H = Metabolite('H',name='H', compartment='c')

## Cofactors and other factors

NAD = Metabolite('NAD', name='NAD', compartment='c')
NADH = Metabolite('NADH', name='NADH', compartment='c')
ADP = Metabolite('ADP', name='ADP', formula='C10H15N5O10P2', compartment='c')
ATP = Metabolite('ATP', name='ATP', formula='C10H16N5O13P3', compartment='c')
CO2 = Metabolite('CO2', name='CO2', formula='C1O2', compartment='c')

## Reactions

# Entry A
reaction = Reaction('A_Tr')
reaction.name = 'A_Tr'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({A: 1.0})
model.add_reactions([reaction])
# Entry B
reaction = Reaction('B_Tr')
reaction.name = 'B_Tr'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({B: 1.0})
model.add_reactions([reaction])
# Output E
reaction = Reaction('E_Tr')
reaction.name = 'E_Tr'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({E: -1.0})
model.add_reactions([reaction])
# Output G
reaction = Reaction('G_Tr')
reaction.name = 'G_Tr'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({G: -1.0})
model.add_reactions([reaction])
# Output H
reaction = Reaction('H_Tr')
reaction.name = 'H_Tr'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({H: -1.0})
model.add_reactions([reaction])
# Output CO2
reaction = Reaction('CO2_Tr')
reaction.name = 'CO2_Tr'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({CO2: -1.0})
model.add_reactions([reaction])

#Reactions in the models

#v_1: A + ATP --> C + CO2 +ADP
reaction = Reaction('v_1')
reaction.name = 'v_1'
reaction.lower_bound = -1000
reaction.upper_bound = 1000
reaction.add_metabolites({A: -1.0, ATP: -1.0, C: 1.0, CO2: 1.0, ADP: 1.0})
model.add_reactions([reaction])
#v_2: B + NAD --> C + NADH
reaction = Reaction('v_2')
reaction.name = 'v_2'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({B: -1.0, NAD: -1.0, C: 1.0, NADH: 1.0})
model.add_reactions([reaction])
#v_3: C + NAD --> D + NADH
reaction = Reaction('v_3')
reaction.name = 'v_3'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({C: -1.0, ADP: -1.0, D: 1.0, ATP: 1.0})
model.add_reactions([reaction])
#v_4: C --> E + CO2
reaction = Reaction('v_4')
reaction.name = 'v_4'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({C: -1.0, E: 1.0, CO2: 1.0})
model.add_reactions([reaction])
#v_5: D + ATP --> F + CO2 + ADP
reaction = Reaction('v_5')
reaction.name = 'v_5'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({D: -1.0, ATP: -1.0, F: 1.0, CO2: 1.0, ATP: 1.0})
model.add_reactions([reaction])
#v_6: D + NADH --> G + NAD
reaction = Reaction('v_6')
reaction.name = 'v_6'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({D: -1.0, NADH: -1.0, G: 1.0, NAD: 1.0})
model.add_reactions([reaction])
#v_7: F + NADH + ATP --> H + NAD +ADP
reaction = Reaction('v_7')
reaction.name = 'v_7'
reaction.lower_bound = 0
reaction.upper_bound = 1000
reaction.add_metabolites({F: -1.0, NADH: -1.0, ATP: -1.0, H: 1.0, NAD: 1.0, ADP: 1.0})
model.add_reactions([reaction])

## Flux Balance Analysis

model.objective = 'v_6'
solution = model.optimize()

# %%
model.metabolites.ATP.summary()
# Out:
# <h3>ATP</h3><p>C10H16N5O13P3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>500</td>
#       <td>v_3</td>
#       <td>ADP + C --&gt; ATP + D</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-500</td>
#       <td>v_1</td>
#       <td>A + ATP &lt;=&gt; ADP + C + CO2</td>
#     </tr>
#   </tbody>
# </table>
