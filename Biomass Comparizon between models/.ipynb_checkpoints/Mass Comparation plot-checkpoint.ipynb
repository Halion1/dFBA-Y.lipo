# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the excel file
dfnew = pd.read_excel('concentrationresultados1.1.xlsx')
dfold = pd.read_excel('concentrationresultados1.2.xlsx')

# %%
# Add a new column to each dataframe that will serve as an identifier
dfnew['Condition'] = 'New'

# %%
dfold['Condition'] = 'Old'

# %%
# Combine the two dataframes
df = pd.concat([dfnew, dfold])

# %%
# Reshape the dataframe so that one column contains all biomass values
df_melted = df.melt(id_vars=['time', 'Condition'], value_name='Biomass')
# Out:
# /home/jeremy/anaconda3/envs/dfba/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.

# %%
# Create the plot
sns.lineplot(data=df_melted, x='time', y='Biomass', hue='Condition', ci=None, markers=True)

# Customize the plot
plt.title('Biomass Growth Comparison')
plt.xlabel('Time [h]')
plt.ylabel('Biomass')
plt.legend(title='Condition')

# Show the plot
plt.show()
# Out:
# /home/jeremy/anaconda3/envs/dfba/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %%
# Load the excel file
fbanew = pd.read_excel('solutions1.1_fba_fluxes.xlsx')
fbaold = pd.read_excel('solutions1.2_fba_fluxes.xlsx')

# %%
# Add a new column to each dataframe that will serve as an identifier
fbaold['Condition'] = 'Old'
fbanew['Condition'] = 'New'

# %%
# Load the excel file
fbanewtry = pd.read_excel('newtryheatmap.xlsx')
# Set Name as the index of the DataFrame
fbanewtry.set_index('names', inplace=True)

# %%
fbanewtry
# Out:
#                  newfluxes     oldfluxes
# names
# xAMINOACID    1.056916e-01  1.056916e-01
# xBIOMASS      1.056916e-01  1.056916e-01
# xLIPID        1.056916e-04  1.056916e-04
# xMAINTENANCE  0.000000e+00  0.000000e+00
# xPOOL_AC_EM   1.194860e-02  1.194860e-02
# ...                    ...           ...
# y300041       2.276543e-32  0.000000e+00
# y300057      -2.378062e-02 -2.378062e-02
# y300061       0.000000e+00 -5.186823e-16
# y300076       4.047990e-03  4.047990e-03
# y300077       0.000000e+00  2.775558e-17
#
# [510 rows x 2 columns]

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(fbanewtry, cmap='YlGnBu', vmin=-0.2, vmax=0.2)
# Out:
# <AxesSubplot:ylabel='names'>

# %%
df_filtered1 = fbanewtry[abs(abs(fbanewtry['oldfluxes']) - abs(fbanewtry['newfluxes'])) >= 0.01]

# %%
df_filtered1
# Out:
#          newfluxes  oldfluxes
# names
# y000446  -0.819445  -0.793582
# y000499   0.000000   0.025863
# y000851  -0.024203  -0.065212
# y001063   0.056651   0.015642
# y001112  -2.889187   0.038260
# y001126  -2.927448   0.000000
# y001824   8.215431   8.189568
# y001832  -8.265718  -8.239855
# y002117   0.000000   0.041008
# y002119  -0.041008   0.000000
# y002132   0.000000   2.932557
# y200001   0.025863   0.000000

# %%
df_filtered2 = fbanewtry[abs(abs(fbanewtry['newfluxes']) - abs(fbanewtry['oldfluxes'])) >= 0.01]

# %%
df_filtered2
# Out:
#          newfluxes  oldfluxes
# names
# y000446  -0.819445  -0.793582
# y000499   0.000000   0.025863
# y000851  -0.024203  -0.065212
# y001063   0.056651   0.015642
# y001112  -2.889187   0.038260
# y001126  -2.927448   0.000000
# y001824   8.215431   8.189568
# y001832  -8.265718  -8.239855
# y002117   0.000000   0.041008
# y002119  -0.041008   0.000000
# y002132   0.000000   2.932557
# y200001   0.025863   0.000000

# %%
# Load the excel file
fbanewtry2 = pd.read_excel('heatmapdatabiomassoptimization2.xlsx')
# Set Name as the index of the DataFrame
fbanewtry2.set_index('names', inplace=True)

# %%
fbanewtry2
# Out:
#                original iYali     new iYali    W29 strain  Obese strain  \
# names
# xAMINOACID           0.105692  1.056916e-01  1.057127e-01  1.057127e-01
# xBIOMASS             0.105692  1.056916e-01  1.057127e-01  1.057127e-01
# xLIPID               0.000106  1.056916e-04  1.057127e-04  1.057127e-04
# xMAINTENANCE         0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_AC_EM          0.011949  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_AC_LP          0.000000  1.194860e-02  1.195098e-02  1.195098e-02
# xPOOL_AC_MM          0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_FA_EM          0.000000  9.352099e-21  0.000000e+00  0.000000e+00
# xPOOL_FA_EN          0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_FA_LP          0.000350  3.503050e-04  3.503749e-04  3.503749e-04
# xPOOL_FA_MI          0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_FA_MM          0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y000108              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y000109              0.091504  9.150367e-02  9.152191e-02  9.152191e-02
# y000831              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y002202             -0.000128 -1.386216e-04  2.270687e-03  2.270687e-03
# y002204              0.000000 -1.471281e-05 -2.413481e-03 -2.413481e-03
# y002205              0.000198 -1.804071e-04 -1.804431e-04 -1.804431e-04
# y003253              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y003255              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y003257              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y003258              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y003259              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y003261              0.000000 -4.816331e-21  0.000000e+00  0.000000e+00
# y003573              0.000015  0.000000e+00 -2.398765e-03 -2.398765e-03
# y003574              0.000378  0.000000e+00  0.000000e+00  0.000000e+00
# y300059              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y300083              0.000000  0.000000e+00  5.475919e-02  5.475919e-02
# y300084              0.000000  0.000000e+00  5.475919e-02  5.475919e-02
# y300085              0.000000  0.000000e+00  5.475919e-02  5.475919e-02
# y300086              0.000000  0.000000e+00  5.475919e-02  5.475919e-02
# y300091              0.000000  0.000000e+00 -5.475919e-02 -5.475919e-02
# y300094              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y300099              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y300100              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y300102              0.000000 -1.448404e-15 -2.032195e-17  3.885781e-16
# y300104              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y300105              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# y300106              0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_PC_M           0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_PC_C           0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_FA_C           0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_FA_P           0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_MA_M           0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_SU_C           0.000000  1.448404e-15  0.000000e+00 -4.383705e-17
# xPOOL_SU_M           0.000000 -1.448404e-15  0.000000e+00 -1.049291e-17
# xPOOL_ECFA_LP        0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# xPOOL_OCFA_LP        0.000000  0.000000e+00  0.000000e+00  0.000000e+00
#
#                enhanced new iYali
# names
# xAMINOACID           0.000000e+00
# xBIOMASS             0.000000e+00
# xLIPID               0.000000e+00
# xMAINTENANCE         0.000000e+00
# xPOOL_AC_EM         -5.710761e-17
# xPOOL_AC_LP          0.000000e+00
# xPOOL_AC_MM          8.942222e-18
# xPOOL_FA_EM          3.111313e-17
# xPOOL_FA_EN          0.000000e+00
# xPOOL_FA_LP          0.000000e+00
# xPOOL_FA_MI          0.000000e+00
# xPOOL_FA_MM          0.000000e+00
# y000108              0.000000e+00
# y000109              0.000000e+00
# y000831              0.000000e+00
# y002202              0.000000e+00
# y002204             -9.873683e-18
# y002205              4.605244e-18
# y003253              0.000000e+00
# y003255              0.000000e+00
# y003257              0.000000e+00
# y003258              0.000000e+00
# y003259              0.000000e+00
# y003261              0.000000e+00
# y003573             -9.873683e-18
# y003574              4.605244e-18
# y300059              9.434495e-03
# y300083              0.000000e+00
# y300084              0.000000e+00
# y300085              0.000000e+00
# y300086             -1.258518e-01
# y300091              2.831446e-02
# y300094              0.000000e+00
# y300099              1.573148e-02
# y300100              1.573148e-02
# y300102              1.573148e-02
# y300104              0.000000e+00
# y300105              0.000000e+00
# y300106              0.000000e+00
# xPOOL_PC_M           0.000000e+00
# xPOOL_PC_C           0.000000e+00
# xPOOL_FA_C           0.000000e+00
# xPOOL_FA_P           0.000000e+00
# xPOOL_MA_M           0.000000e+00
# xPOOL_SU_C          -1.573148e-02
# xPOOL_SU_M          -3.469447e-18
# xPOOL_ECFA_LP        0.000000e+00
# xPOOL_OCFA_LP        0.000000e+00

# %%
from matplotlib.colors import LinearSegmentedColormap

# Define color map
cmap = LinearSegmentedColormap.from_list('mycmap', ['blue', 'white', 'red'])

plt.figure(figsize=(8, 10))
sns.heatmap(fbanewtry2, vmin=0, vmax=0.1, annot=True, linewidth=.1, cmap=cmap, cbar_kws={'label': 'Flux (mmol*gDW*h^-1)'})
plt.savefig("heatmapconditionsbiomass.jpg", dpi=500, bbox_inches='tight')

# %%
# Load the excel file
fbanewtry2 = pd.read_excel('heatmapdatabiomassoptimization2.xlsx')
# Set Name as the index of the DataFrame
fbanewtry2.set_index('names', inplace=True)

# %%
from matplotlib.colors import LinearSegmentedColormap

# Define color map
cmap = LinearSegmentedColormap.from_list('mycmap', ['blue', 'white', 'red'])

plt.figure(figsize=(8, 10))
sns.heatmap(fbanewtry2, vmin=-0.1, vmax=0.1, annot=True, linewidth=.1, cmap=cmap, cbar_kws={'label': 'Flux (mmol*gDW*h^-1)'})
plt.savefig("heatmapconditionsbiomass.jpg", dpi=500, bbox_inches='tight')

# %%
from matplotlib.colors import LinearSegmentedColormap

# Define color map
cmap = LinearSegmentedColormap.from_list('mycmap', ['blue', 'white', 'red'])

plt.figure(figsize=(8, 10))
sns_heatmap = sns.heatmap(fbanewtry2, vmin=-0.1, vmax=0.1, annot=True, linewidth=4, cmap=cmap, cbar_kws={'label': 'Flux (mmol*gDW*h^-1)'})

# Get a handle on the colorbar object
cbar = sns_heatmap.collections[0].colorbar

# Set the colorbar label orientation
cbar.set_label('Flux (mmol*gDW*h^-1)', rotation=0, labelpad=70)

plt.savefig("heatmapconditionsbiomass.jpg", dpi=500, bbox_inches='tight')

# %%
from matplotlib.colors import LinearSegmentedColormap

# Define color map
cmap = LinearSegmentedColormap.from_list('mycmap', ['blue', 'white', 'red'])

plt.figure(figsize=(8, 10))
sns_heatmap = sns.heatmap(fbanewtry2, vmin=-0.1, vmax=0.1, annot=True, linewidth=1, cmap=cmap, linecolor='black', cbar_kws={'label': 'Flux (mmol*gDW*h^-1)'})

# Get a handle on the colorbar object
cbar = sns_heatmap.collections[0].colorbar

# Set the colorbar label orientation
cbar.set_label('Flux (mmol*gDW*h^-1)', rotation=0, labelpad=70)

plt.savefig("heatmapconditionsbiomass.jpg", dpi=500, bbox_inches='tight')
